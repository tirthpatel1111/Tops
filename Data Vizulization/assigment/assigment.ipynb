# %% [markdown]
# ## Write an essay: Importance of Data Cleaning in Data Science
#
# Essay: The Importance of Data Cleaning in Data Science
#
# Data has become the cornerstone of decision-making in the modern world. From shaping business strategies to driving innovations in healthcare and finance, data science plays a crucial role across sectors. However, the effectiveness of data science depends heavily on the quality of the data used. This is where data cleaning—the process of detecting and correcting (or removing) corrupt or inaccurate records from a dataset—becomes essential. Without it, even the most advanced algorithms can produce misleading insights, leading to poor decisions and lost opportunities.
#
# 1. Ensuring Data Accuracy and Consistency
# One of the primary goals of data cleaning is to ensure accuracy. Datasets often contain errors such as typos, duplicates, missing values, or inconsistent formatting. These anomalies can distort statistical measures, affect model training, and ultimately result in flawed conclusions.
#
# 2. Improving Model Performance
# Machine learning algorithms are particularly sensitive to the quality of data. Models trained on noisy or inconsistent data are more likely to underperform, overfit, or produce biased results. Data cleaning helps ensure that the features fed into the model are representative and free from unnecessary noise.
#
# 3. Enhancing Data Usability and Interpretability
# Clean data is not only more accurate but also easier to work with. When datasets are well-structured and free of inconsistencies, they can be more readily explored, visualized, and interpreted. This makes it easier for data scientists and stakeholders to draw meaningful insights and make informed decisions.
#
# 4. Reducing Costs and Saving Time
# Cleaning data early in the data pipeline saves significant time and resources in the later stages of analysis and model deployment. Unclean data leads to repeated debugging, misinterpretations, and rework, all of which add to project costs.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('data.csv')

# %%
df.head(5)
# Out:
#   Make       Model  Year             Engine Fuel Type  Engine HP  \
# 0  BMW  1 Series M  2011  premium unleaded (required)      335.0
# 1  BMW    1 Series  2011  premium unleaded (required)      300.0
# 2  BMW    1 Series  2011  premium unleaded (required)      300.0
# 3  BMW    1 Series  2011  premium unleaded (required)      230.0
# 4  BMW    1 Series  2011  premium unleaded (required)      230.0
#
#    Engine Cylinders Transmission Type     Driven_Wheels  Number of Doors  \
# 0               6.0            MANUAL  rear wheel drive              2.0
# 1               6.0            MANUAL  rear wheel drive              2.0
# 2               6.0            MANUAL  rear wheel drive              2.0
# 3               6.0            MANUAL  rear wheel drive              2.0
# 4               6.0            MANUAL  rear wheel drive              2.0
#
#                          Market Category Vehicle Size Vehicle Style  \
# 0  Factory Tuner,Luxury,High-Performance      Compact         Coupe
# 1                     Luxury,Performance      Compact   Convertible
# 2                Luxury,High-Performance      Compact         Coupe
# 3                     Luxury,Performance      Compact         Coupe
# 4                                 Luxury      Compact   Convertible
#
#    highway MPG  city mpg  Popularity   MSRP
# 0           26        19        3916  46135
# 1           28        19        3916  40650
# 2           28        20        3916  36350
# 3           28        18        3916  29450
# 4           28        18        3916  34500

# %% [markdown]
# ## Data Cleaning

# %%
df[df['Driven_Wheels']=="all wheel drive"]
# Out:
#         Make Model  Year                Engine Fuel Type  Engine HP  \
# 19      Audi   100  1992                regular unleaded      172.0
# 21      Audi   100  1992                regular unleaded      172.0
# 23      Audi   100  1993                regular unleaded      172.0
# 26      Audi   100  1993                regular unleaded      172.0
# 28      Audi   100  1994                regular unleaded      172.0
# ...      ...   ...   ...                             ...        ...
# 11908  Acura   ZDX  2011     premium unleaded (required)      300.0
# 11909  Acura   ZDX  2012     premium unleaded (required)      300.0
# 11910  Acura   ZDX  2012     premium unleaded (required)      300.0
# 11911  Acura   ZDX  2012     premium unleaded (required)      300.0
# 11912  Acura   ZDX  2013  premium unleaded (recommended)      300.0
#
#        Engine Cylinders Transmission Type    Driven_Wheels  Number of Doors  \
# 19                  6.0         AUTOMATIC  all wheel drive              4.0
# 21                  6.0            MANUAL  all wheel drive              4.0
# 23                  6.0         AUTOMATIC  all wheel drive              4.0
# 26                  6.0            MANUAL  all wheel drive              4.0
# 28                  6.0            MANUAL  all wheel drive              4.0
# ...                 ...               ...              ...              ...
# 11908               6.0         AUTOMATIC  all wheel drive              4.0
# 11909               6.0         AUTOMATIC  all wheel drive              4.0
# 11910               6.0         AUTOMATIC  all wheel drive              4.0
# 11911               6.0         AUTOMATIC  all wheel drive              4.0
# 11912               6.0         AUTOMATIC  all wheel drive              4.0
#
#                   Market Category Vehicle Size  Vehicle Style  highway MPG  \
# 19                         Luxury      Midsize          Wagon           20
# 21                         Luxury      Midsize          Sedan           21
# 23                         Luxury      Midsize          Wagon           20
# 26                         Luxury      Midsize          Sedan           21
# 28                         Luxury      Midsize          Sedan           22
# ...                           ...          ...            ...          ...
# 11908  Crossover,Hatchback,Luxury      Midsize  4dr Hatchback           23
# 11909  Crossover,Hatchback,Luxury      Midsize  4dr Hatchback           23
# 11910  Crossover,Hatchback,Luxury      Midsize  4dr Hatchback           23
# 11911  Crossover,Hatchback,Luxury      Midsize  4dr Hatchback           23
# 11912  Crossover,Hatchback,Luxury      Midsize  4dr Hatchback           23
#
#        city mpg  Popularity   MSRP
# 19           16        3105   2000
# 21           16        3105   2000
# 23           16        3105   2000
# 26           16        3105   2000
# 28           16        3105   2000
# ...         ...         ...    ...
# 11908        16         204  50520
# 11909        16         204  46120
# 11910        16         204  56670
# 11911        16         204  50620
# 11912        16         204  50920
#
# [2353 rows x 16 columns]

# %%
df[df['Driven_Wheels']=="four wheel drive"]
# Out:
#          Make    Model  Year                Engine Fuel Type  Engine HP  \
# 481    Toyota  4Runner  2014                regular unleaded      270.0
# 482    Toyota  4Runner  2014                regular unleaded      270.0
# 483    Toyota  4Runner  2014                regular unleaded      270.0
# 484    Toyota  4Runner  2014                regular unleaded      270.0
# 486    Toyota  4Runner  2014                regular unleaded      270.0
# ...       ...      ...   ...                             ...        ...
# 11871     GMC    Yukon  2016  premium unleaded (recommended)      420.0
# 11874     GMC    Yukon  2016        flex-fuel (unleaded/E85)      355.0
# 11875     GMC    Yukon  2017  premium unleaded (recommended)      420.0
# 11877     GMC    Yukon  2017        flex-fuel (unleaded/E85)      355.0
# 11879     GMC    Yukon  2017        flex-fuel (unleaded/E85)      355.0
#
#        Engine Cylinders Transmission Type     Driven_Wheels  Number of Doors  \
# 481                 6.0         AUTOMATIC  four wheel drive              4.0
# 482                 6.0         AUTOMATIC  four wheel drive              4.0
# 483                 6.0         AUTOMATIC  four wheel drive              4.0
# 484                 6.0         AUTOMATIC  four wheel drive              4.0
# 486                 6.0         AUTOMATIC  four wheel drive              4.0
# ...                 ...               ...               ...              ...
# 11871               8.0         AUTOMATIC  four wheel drive              4.0
# 11874               8.0         AUTOMATIC  four wheel drive              4.0
# 11875               8.0         AUTOMATIC  four wheel drive              4.0
# 11877               8.0         AUTOMATIC  four wheel drive              4.0
# 11879               8.0         AUTOMATIC  four wheel drive              4.0
#
#              Market Category Vehicle Size Vehicle Style  highway MPG  \
# 481                      NaN      Midsize       4dr SUV           22
# 482                      NaN      Midsize       4dr SUV           22
# 483                      NaN      Midsize       4dr SUV           22
# 484                      NaN      Midsize       4dr SUV           22
# 486                      NaN      Midsize       4dr SUV           22
# ...                      ...          ...           ...          ...
# 11871            Performance        Large       4dr SUV           21
# 11874  Flex Fuel,Performance        Large       4dr SUV           22
# 11875            Performance        Large       4dr SUV           20
# 11877  Flex Fuel,Performance        Large       4dr SUV           22
# 11879  Flex Fuel,Performance        Large       4dr SUV           22
#
#        city mpg  Popularity   MSRP
# 481          17        2031  37615
# 482          17        2031  34695
# 483          17        2031  35725
# 484          17        2031  43400
# 486          17        2031  38645
# ...         ...         ...    ...
# 11871        15         549  68325
# 11874        16         549  60000
# 11875        15         549  68965
# 11877        16         549  51530
# 11879        16         549  60315
#
# [1403 rows x 16 columns]

# %%
df['Driven_Wheels'].value_counts()
# Out:
# Driven_Wheels
# front wheel drive    4787
# rear wheel drive     3371
# all wheel drive      2353
# four wheel drive     1403
# Name: count, dtype: int64

# %%
def convert(x):
    
    x.replace("all wheel drive","four wheel drive",inplace=True)
    return x

# %%
df['Driven_Wheels']=convert(df['Driven_Wheels'])

# %% [markdown]
# Here four-wheel type and all-wheel type are same so we convert all wheel types into four wheel types

# %%
df['Transmission Type'].value_counts()
# Out:
# Transmission Type
# AUTOMATIC           8266
# MANUAL              2935
# AUTOMATED_MANUAL     626
# DIRECT_DRIVE          68
# UNKNOWN               19
# Name: count, dtype: int64

# %%
df.drop(df[df['Transmission Type']=='UNKNOWN'].index, inplace=True)

# %% [markdown]
# It remove rows of unkown categories of transmission type

# %%
df['Engine Fuel Type'].value_counts()
# Out:
# Engine Fuel Type
# regular unleaded                                7153
# premium unleaded (required)                     2009
# premium unleaded (recommended)                  1523
# flex-fuel (unleaded/E85)                         899
# diesel                                           154
# electric                                          66
# flex-fuel (premium unleaded required/E85)         54
# flex-fuel (premium unleaded recommended/E85)      26
# flex-fuel (unleaded/natural gas)                   6
# natural gas                                        2
# Name: count, dtype: int64

# %%
df.loc[df['Engine Fuel Type'].isin(['regular unleaded','premium unleaded (required)','premium unleaded (recommended)','flex-fuel (premium unleaded required/E85)','flex-fuel (premium unleaded recommended/E85)','flex-fuel (unleaded/E85)']),'Engine Fuel Type'] = 'Petrol'

# %%
df.loc[df['Engine Fuel Type'].isin(['flex-fuel (unleaded/natural gas)']),'Engine Fuel Type'] = 'Natural Gas'

# %%
df['Engine Fuel Type'].value_counts()
# Out:
# Engine Fuel Type
# Petrol         11664
# diesel           154
# electric          66
# Natural Gas        6
# natural gas        2
# Name: count, dtype: int64

# %% [markdown]
# it convert 'regular unleaded','premium unleaded (required)','premium unleaded (recommended)','flex-fuel (premium unleaded required/E85)','flex-fuel (premium unleaded recommended/E85)','flex-fuel (unleaded/E85)' fuel category into petrol and 'flex-fuel (unleaded/natural gas)' cetagory into natural gas

# %%
df.head()
# Out:
#   Make       Model  Year Engine Fuel Type  Engine HP  Engine Cylinders  \
# 0  BMW  1 Series M  2011           Petrol      335.0               6.0
# 1  BMW    1 Series  2011           Petrol      300.0               6.0
# 2  BMW    1 Series  2011           Petrol      300.0               6.0
# 3  BMW    1 Series  2011           Petrol      230.0               6.0
# 4  BMW    1 Series  2011           Petrol      230.0               6.0
#
#   Transmission Type     Driven_Wheels  Number of Doors  \
# 0            MANUAL  rear wheel drive              2.0
# 1            MANUAL  rear wheel drive              2.0
# 2            MANUAL  rear wheel drive              2.0
# 3            MANUAL  rear wheel drive              2.0
# 4            MANUAL  rear wheel drive              2.0
#
#                          Market Category Vehicle Size Vehicle Style  \
# 0  Factory Tuner,Luxury,High-Performance      Compact         Coupe
# 1                     Luxury,Performance      Compact   Convertible
# 2                Luxury,High-Performance      Compact         Coupe
# 3                     Luxury,Performance      Compact         Coupe
# 4                                 Luxury      Compact   Convertible
#
#    highway MPG  city mpg  Popularity   MSRP
# 0           26        19        3916  46135
# 1           28        19        3916  40650
# 2           28        20        3916  36350
# 3           28        18        3916  29450
# 4           28        18        3916  34500

# %%
df.isnull().sum()
# Out:
# Make                    0
# Model                   0
# Year                    0
# Engine Fuel Type        3
# Engine HP              69
# Engine Cylinders       30
# Transmission Type       0
# Driven_Wheels           0
# Number of Doors         6
# Market Category      3726
# Vehicle Size            0
# Vehicle Style           0
# highway MPG             0
# city mpg                0
# Popularity              0
# MSRP                    0
# dtype: int64

# %%
df['Engine Fuel Type'].fillna(df['Engine Fuel Type'].mode(), inplace=True)
# Out:
# C:\Users\tp338\AppData\Local\Temp\ipykernel_23824\465765625.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Engine Fuel Type'].fillna(df['Engine Fuel Type'].mode(), inplace=True)

# %%
df['Engine HP'].fillna(df['Engine HP'].mean(), inplace=True)
# Out:
# C:\Users\tp338\AppData\Local\Temp\ipykernel_23824\2846301960.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Engine HP'].fillna(df['Engine HP'].mean(), inplace=True)

# %% [markdown]
# it fill null value of engine hp using null

# %%
df['Engine Cylinders'].fillna(df['Engine Cylinders'].mean(), inplace=True)
# Out:
# C:\Users\tp338\AppData\Local\Temp\ipykernel_23824\3959053558.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Engine Cylinders'].fillna(df['Engine Cylinders'].mean(), inplace=True)

# %%
df['Vehicle Style'].value_counts()
# Out:
# Vehicle Style
# Sedan                  3047
# 4dr SUV                2488
# Coupe                  1209
# Convertible             791
# 4dr Hatchback           702
# Crew Cab Pickup         681
# Extended Cab Pickup     623
# Wagon                   592
# 2dr Hatchback           504
# Passenger Minivan       417
# Regular Cab Pickup      384
# 2dr SUV                 134
# Passenger Van           128
# Cargo Van                95
# Cargo Minivan            71
# Convertible SUV          29
# Name: count, dtype: int64

# %%
df['Vehicle Style'].unique()
# Out:
# array(['Coupe', 'Convertible', 'Sedan', 'Wagon', '4dr Hatchback',
#        '2dr Hatchback', '4dr SUV', 'Passenger Minivan', 'Cargo Minivan',
#        'Crew Cab Pickup', 'Regular Cab Pickup', 'Extended Cab Pickup',
#        '2dr SUV', 'Cargo Van', 'Convertible SUV', 'Passenger Van'],
#       dtype=object)

# %%
df[df['Vehicle Style'] == 'Cargo Van']['Market Category'].mode()
# Out:
# 0    Flex Fuel
# Name: Market Category, dtype: object

# %%
def fillcat(df,x,y):
    for unique in df[y].unique():
        subset=df[df[y]==unique]
        mode_value=subset[x].mode()
        if not mode_value.empty:
            df.loc[
                (df[y]==unique)&(df[x].isnull()),
                x
                ] = mode_value[0]
    return df

# %%
fillcat(df,'Market Category', 'Vehicle Style')
# Out:
#           Make       Model  Year Engine Fuel Type  Engine HP  \
# 0          BMW  1 Series M  2011           Petrol      335.0
# 1          BMW    1 Series  2011           Petrol      300.0
# 2          BMW    1 Series  2011           Petrol      300.0
# 3          BMW    1 Series  2011           Petrol      230.0
# 4          BMW    1 Series  2011           Petrol      230.0
# ...        ...         ...   ...              ...        ...
# 11909    Acura         ZDX  2012           Petrol      300.0
# 11910    Acura         ZDX  2012           Petrol      300.0
# 11911    Acura         ZDX  2012           Petrol      300.0
# 11912    Acura         ZDX  2013           Petrol      300.0
# 11913  Lincoln      Zephyr  2006           Petrol      221.0
#
#        Engine Cylinders Transmission Type      Driven_Wheels  Number of Doors  \
# 0                   6.0            MANUAL   rear wheel drive              2.0
# 1                   6.0            MANUAL   rear wheel drive              2.0
# 2                   6.0            MANUAL   rear wheel drive              2.0
# 3                   6.0            MANUAL   rear wheel drive              2.0
# 4                   6.0            MANUAL   rear wheel drive              2.0
# ...                 ...               ...                ...              ...
# 11909               6.0         AUTOMATIC   four wheel drive              4.0
# 11910               6.0         AUTOMATIC   four wheel drive              4.0
# 11911               6.0         AUTOMATIC   four wheel drive              4.0
# 11912               6.0         AUTOMATIC   four wheel drive              4.0
# 11913               6.0         AUTOMATIC  front wheel drive              4.0
#
#                              Market Category Vehicle Size  Vehicle Style  \
# 0      Factory Tuner,Luxury,High-Performance      Compact          Coupe
# 1                         Luxury,Performance      Compact    Convertible
# 2                    Luxury,High-Performance      Compact          Coupe
# 3                         Luxury,Performance      Compact          Coupe
# 4                                     Luxury      Compact    Convertible
# ...                                      ...          ...            ...
# 11909             Crossover,Hatchback,Luxury      Midsize  4dr Hatchback
# 11910             Crossover,Hatchback,Luxury      Midsize  4dr Hatchback
# 11911             Crossover,Hatchback,Luxury      Midsize  4dr Hatchback
# 11912             Crossover,Hatchback,Luxury      Midsize  4dr Hatchback
# 11913                                 Luxury      Midsize          Sedan
#
#        highway MPG  city mpg  Popularity   MSRP
# 0               26        19        3916  46135
# 1               28        19        3916  40650
# 2               28        20        3916  36350
# 3               28        18        3916  29450
# 4               28        18        3916  34500
# ...            ...       ...         ...    ...
# 11909           23        16         204  46120
# 11910           23        16         204  56670
# 11911           23        16         204  50620
# 11912           23        16         204  50920
# 11913           26        17          61  28995
#
# [11895 rows x 16 columns]

# %% [markdown]
# it very intresting cetogericol value filling opration we can fill value of market category based on vehicle style.we create a unique categorical list of vehicle style col and find subset of df after in this subset we fine mode of market cetegory mode and fill null values

# %%
df.isnull().sum()
# Out:
# Make                 0
# Model                0
# Year                 0
# Engine Fuel Type     3
# Engine HP            0
# Engine Cylinders     0
# Transmission Type    0
# Driven_Wheels        0
# Number of Doors      6
# Market Category      0
# Vehicle Size         0
# Vehicle Style        0
# highway MPG          0
# city mpg             0
# Popularity           0
# MSRP                 0
# dtype: int64

# %% [markdown]
# ## Data Vizulization

# %%
sns.histplot(df['Engine HP'], bins=100, kde=True)
# Out:
# <Axes: xlabel='Engine HP', ylabel='Count'>

# %% [markdown]
# Their is hist plot of engine hp which show that most of the car's horse power either 200 or 300

# %%
df['Make'].value_counts().head(5)
# Out:
# Make
# Chevrolet     1123
# Ford           881
# Volkswagen     809
# Toyota         746
# Dodge          618
# Name: count, dtype: int64

# %%
subset = df[df['Make'].isin(['Chevrolet', 'Ford','Volkswagen','Toyota','Dodge'])].groupby(['Make','Vehicle Size']).size().reset_index(name='Count')
plt.figure(figsize=(10, 6))
sns.barplot(data=subset, x='Make', y='Count', hue='Vehicle Size')
plt.title('Vehicle Size by top 5 Make Companys')
# Out:
# Text(0.5, 1.0, 'Vehicle Size by top 5 Make Companys')

# %% [markdown]
# This barplot show that top 5 making company which type of vehicles make and how many numbers

# %%
df.corr(numeric_only=True)
# Out:
#                       Year  Engine HP  Engine Cylinders  Number of Doors  \
# Year              1.000000   0.349925         -0.041310         0.260294
# Engine HP         0.349925   1.000000          0.765518        -0.104651
# Engine Cylinders -0.041310   0.765518          1.000000        -0.139753
# Number of Doors   0.260294  -0.104651         -0.139753         1.000000
# highway MPG       0.256859  -0.354712         -0.602500         0.116991
# city mpg          0.196936  -0.347369         -0.567076         0.119642
# Popularity        0.072559   0.037258          0.041267        -0.049119
# MSRP              0.226415   0.661561          0.531763        -0.128440
#
#                   highway MPG  city mpg  Popularity      MSRP
# Year                 0.256859  0.196936    0.072559  0.226415
# Engine HP           -0.354712 -0.347369    0.037258  0.661561
# Engine Cylinders    -0.602500 -0.567076    0.041267  0.531763
# Number of Doors      0.116991  0.119642   -0.049119 -0.128440
# highway MPG          1.000000  0.886770   -0.021122 -0.160883
# city mpg             0.886770  1.000000   -0.003384 -0.158366
# Popularity          -0.021122 -0.003384    1.000000 -0.048850
# MSRP                -0.160883 -0.158366   -0.048850  1.000000

# %% [markdown]
# This correlation table give relation between each other for numeric values.It show that how Effect of columns Depanding of another columns value increasing or Decreasing.

# %%
plt.scatter(x='Engine HP', y='Engine Cylinders', data=df, alpha=0.5)

# %% [markdown]
# This scatter plot Define that how many engine cylinders are use full for engine hourse power.

# %%
df[df['Transmission Type']=='AUTOMATIC']['highway MPG'].mean()
# Out:
# np.float64(25.782966368255504)

# %%
means = df[df['Transmission Type'].isin(['AUTOMATIC', 'MANUAL'])].groupby('Transmission Type')['highway MPG'].mean()
plt.bar(means.index, means.values, color=['blue', 'orange'])
plt.xlabel('Transmission Type')
plt.ylabel('Mean Highway MPG')
plt.title('Mean Highway MPG by Transmission Type')
plt.show()

# %% [markdown]
# This graph show that average of manual engine on Highway are greater than automatioc engine

# %%
fig=plt.figure(figsize=(10, 6))
ax1=fig.add_subplot(2,1,1)
ax1.plot(df['Engine HP'], df['highway MPG'], 'o', alpha=0.5)
ax2=fig.add_subplot(2,1,2)
ax2.plot(df['Engine HP'], df['city mpg'], 'o', alpha=0.5)

# %% [markdown]
# this graph compare average between city and highway foe engine hourse power

# %%
nsub=df.groupby(['Driven_Wheels','Vehicle Style']).size().reset_index(name='ne').sort_values(by=['Driven_Wheels','ne'], ascending=False).groupby('Driven_Wheels').head(5)
nsub
# Out:
#         Driven_Wheels        Vehicle Style    ne
# 34   rear wheel drive                Coupe   676
# 40   rear wheel drive                Sedan   585
# 32   rear wheel drive          Convertible   450
# 29   rear wheel drive              4dr SUV   377
# 36   rear wheel drive  Extended Cab Pickup   322
# 24  front wheel drive                Sedan  1782
# 18  front wheel drive              4dr SUV   631
# 17  front wheel drive        4dr Hatchback   583
# 16  front wheel drive        2dr Hatchback   473
# 25  front wheel drive                Wagon   357
# 3    four wheel drive              4dr SUV  1480
# 14   four wheel drive                Sedan   680
# 9    four wheel drive      Crew Cab Pickup   383
# 10   four wheel drive  Extended Cab Pickup   301
# 8    four wheel drive                Coupe   197

# %%
sns.barplot(data=nsub,x='Driven_Wheels',y='ne',hue='Vehicle Style')
# Out:
# <Axes: xlabel='Driven_Wheels', ylabel='ne'>

# %% [markdown]
# This graph give inshitsb of top 5 Vehicle style according driven_wheels.this define how many number of vehicle style use in different driven_wheels for top 5 Vehicle style counts.

# %%
luxcount=df[df['Market Category'].str.contains('Luxury')].groupby(['Make']).size().reset_index(name='count').sort_values(by='count', ascending=False).head(10)
luxcount
# Out:
#              Make  count
# 6        Cadillac    397
# 25  Mercedes-Benz    353
# 3             BMW    334
# 17       Infiniti    330
# 2            Audi    328
# 39          Volvo    281
# 0           Acura    252
# 20          Lexus    202
# 21        Lincoln    164
# 36         Suzuki    157

# %%
sns.barplot(data=luxcount,x='Make',y='count')
plt.title("top 10 luxury car companies")
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# this graph give top 5 luxrious making companies

# %%
# Out:
# Engine Fuel Type
# Petrol         11664
# diesel           154
# electric          66
# Natural Gas        6
# natural gas        2
# Name: count, dtype: int64

# %%
sns.relplot(data=df[df['Engine Fuel Type']=='Petrol'], x='Year', y='Engine HP', kind='line')

# %% [markdown]
# The plot shows that engine horsepower (HP) in petrol vehicles has generally increased over the years, reflecting advancements in engine technology and performance demand.
